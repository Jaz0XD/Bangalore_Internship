# %%
import pandas as pd

# %%
df = pd.read_csv("D:\PROJECT\Housing.csv")

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df['new_columns'] = df['bedrooms'] + df['bathrooms']

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
#    new_columns
# 0            6
# 1            8
# 2            5
# 3            6
# ...

# %%
df.sort_values(by = 'price').head(4)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 544  1750000  3850         3          1        2      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 541  1767150  2400         3          1        1       no        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 544              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 542              no              no        0       no      unfurnished
# 541              no              no        0       no   semi-furnished
#
#      new_columns
# 544            4
# 543            4
# 542            3
# 541            4

# %%
df.sort_values(by = 'price', ascending=True).head(4)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 544  1750000  3850         3          1        2      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 541  1767150  2400         3          1        1       no        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 544              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 542              no              no        0       no      unfurnished
# 541              no              no        0       no   semi-furnished
#
#      new_columns
# 544            4
# 543            4
# 542            3
# 541            4

# %%
temp = {'yes':1, 'no':0}

# %%
df['mainroad'].map(temp)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 540    1
# 541    0
# 542    1
# 543    0
# 544    1
# Name: mainroad, Length: 545, dtype: int64

# %%
df['furnishingstatus'].unique()
# Out:
# array([2, 3, 1])

# %%
temp1 = {'unfurnished': 0, 'furnished' : 2, 'semi-furnished': 1}

# %%
df['furnishingstatus'].map(temp1)
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      2
#       ..
# 540    0
# 541    1
# 542    0
# 543    2
# 544    0
# Name: furnishingstatus, Length: 545, dtype: int64

# %%
df['furnishingstatus'] = df['furnishingstatus'].map(temp1)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns
# 0            6
# 1            8
# 2            5
# 3            6
# ...

# %%
df['Query'] = df['guestroom'] + df['airconditioning'] + df['prefarea']

# %%
df['parking'].unique()
# Out:
# array([2, 3, 0, 1])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns     Query
# 0            6  noyesyes
# 1            8   noyesno
# ...

# %%
df.drop(columns='Query')
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
filtered =df[(df['guestroom'] == 'yes') & (df['parking'] >=2)]

# %%
filtered.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 4   11410000  7420         4          1        2      yes       yes      yes
# 8    9870000  8100         4          1        2      yes       yes      yes
# 11   9681000  6000         4          3        2      yes       yes      yes
# 18   8890000  4600         3          2        2      yes       yes       no
# 21   8680000  7155         3          2        1      yes       yes      yes
#
#    hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 4               no             yes        2       no                 2
# 8               no             yes        2      yes                 2
# 11             yes              no        2       no                 1
# 18              no             yes        2       no                 2
# 21              no             yes        2       no                 0
#
#     new_columns      Query
# 4             5   yesyesno
# ...

# %%
filtered.shape
# Out:
# (23, 15)

# %%
filtered[(filtered['airconditioning'] == 'yes') & (filtered['prefarea'] == 'yes')].shape
# Out:
# (7, 15)

# %%
per = 7/23 * 100

# %%
per
# Out:
# 30.434782608695656

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns     Query
# 0            6  noyesyes
# 1            8   noyesno
# ...

# %%
filtered1 = df[(df['guestroom'] == 'yes') & (df['basement'] == 'yes')]

# %%
filtered1.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 4   11410000  7420         4          1        2      yes       yes      yes
# 8    9870000  8100         4          1        2      yes       yes      yes
# 11   9681000  6000         4          3        2      yes       yes      yes
# 16   9100000  6600         4          2        2      yes       yes      yes
# 21   8680000  7155         3          2        1      yes       yes      yes
#
#    hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 4               no             yes        2       no                 2
# 8               no             yes        2      yes                 2
# 11             yes              no        2       no                 1
# 16              no             yes        1      yes                 0
# 21              no             yes        2       no                 0
#
#     new_columns      Query
# 4             5   yesyesno
# ...

# %%
df['avgprice'] = df['price'] / df['area']

# %%
filtered1['avg_price_per_area'] = filtered1['price']/ filtered1['area']
# Out:
# C:\Users\JazXD\AppData\Local\Temp\ipykernel_12760\3530813445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered1['avg_price_per_area'] = filtered1['price']/ filtered1['area']

# %%
filtered1.groupby('furnishingstatus')['avg_price_per_area'].mean()
# Out:
# furnishingstatus
# 0    1080.403721
# 1     953.583838
# 2    1115.162605
# Name: avg_price_per_area, dtype: float64

# %%
filtered1.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 4   11410000  7420         4          1        2      yes       yes      yes
# 8    9870000  8100         4          1        2      yes       yes      yes
# 11   9681000  6000         4          3        2      yes       yes      yes
# 16   9100000  6600         4          2        2      yes       yes      yes
# 21   8680000  7155         3          2        1      yes       yes      yes
#
#    hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 4               no             yes        2       no                 2
# 8               no             yes        2      yes                 2
# 11             yes              no        2       no                 1
# 16              no             yes        1      yes                 0
# 21              no             yes        2       no                 0
#
#     new_columns      Query  avg_price_per_area
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns     Query     avgprice
# 0            6  noyesyes  1792.452830
# ...

# %%
filtered =df[(df['airconditioning'] == 'no') & (df['hotwaterheating'] == 'no')]

# %%
filtered.head()
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 2   12250000   9960         3          2        2      yes        no      yes
# 7   10150000  16200         5          3        2      yes        no       no
# 14   9240000   7800         3          2        2      yes        no       no
# 15   9100000   6000         4          1        2      yes        no      yes
# 27   8400000   8875         3          1        1      yes        no       no
#
#    hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 2               no              no        2      yes                 1
# 7               no              no        0       no                 0
# 14              no              no        0      yes                 1
# 15              no              no        2       no                 1
# 27              no              no        1       no                 1
#
#     new_columns    Query     avgprice
# ...

# %%
filtered.sort_values('price',ascending=False).head(5)
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 2   12250000   9960         3          2        2      yes        no      yes
# 7   10150000  16200         5          3        2      yes        no       no
# 14   9240000   7800         3          2        2      yes        no       no
# 15   9100000   6000         4          1        2      yes        no      yes
# 27   8400000   8875         3          1        1      yes        no       no
#
#    hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 2               no              no        2      yes                 1
# 7               no              no        0       no                 0
# 14              no              no        0      yes                 1
# 15              no              no        2       no                 1
# 27              no              no        1       no                 1
#
#     new_columns    Query     avgprice
# ...

# %%
filtered =df[(df['area'] >= 3000 ) & (df['mainroad'] == 'yes')]

# %%
filtered.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns     Query     avgprice
# 0            6  noyesyes  1792.452830
# ...

# %%
filtered[(filtered['airconditioning'] == 'yes') & (filtered['prefarea'] == 'yes')].shape

# %%
filtered = filtered[(filtered['furnishingstatus'] == 1) & (filtered['parking'] > 2)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 filtered = filtered[(filtered['furnishingstatus'] == 1) & (filtered['parking'] > 2)]
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 filtered.head()
#
# AttributeError: 'tuple' object has no attribute 'head'

# %%
filtered.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 filtered.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns     Query     avgprice
# 0            6  noyesyes  1792.452830
# ...

# %%
fil = df[(df['furnishingstatus'] == 1) & (df['parking'] > 2)]

# %%
fil = fil[(fil)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12760\3653555761.py in ?()
# ----> 1 fil = fil[(fil)]
#
# ~\anaconda3\envs\project_1\lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4090             return self._getitem_slice(key)
#    4091
#    4092         # Do we have a (boolean) DataFrame?
#    4093         if isinstance(key, DataFrame):
# -> 4094             return self.where(key)
#    4095
#    4096         # Do we have a (boolean) 1d indexer?
#    4097         if com.is_bool_indexer(key):
#
# ~\anaconda3\envs\project_1\lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   10999                         stacklevel=2,
#   11000                     )
#   11001
#   11002         other = common.apply_if_callable(other, self)
# > 11003         return self._where(cond, other, inplace, axis, level)
#
# ...

# %%
df.groupby('guestroom')['price'].agg(['mean', 'median', 'count'])
# Out:
#                    mean     median  count
# guestroom
# no         4.544546e+06  4165000.0    448
# yes        5.792897e+06  5495000.0     97

# %%
#For each combination of stories and furnishingstatus, compute the median price only if there are at least 20 houses in that group

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns     Query     avgprice
# 0            6  noyesyes  1792.452830
# ...

# %%
df.shape
# Out:
# (545, 16)

# %%
df['stories'].unique()
# Out:
# array([3, 4, 2, 1])

# %%
df.groupby(['stories', 'furnishingstatus'])['price'].median()
# Out:
# stories  furnishingstatus
# 1        0                   3255000.0
#          1                   4550000.0
#          2                   4235000.0
# 2        0                   3493000.0
#          1                   4410000.0
#          2                   4973500.0
# 3        0                   5985000.0
#          1                   5530000.0
#          2                   6510000.0
# 4        0                   7087500.0
#          1                   7210000.0
#          2                   7420000.0
# Name: price, dtype: float64

# %%
df.groupby(['stories', 'furnishingstatus'])['price'].agg(['median', 'count']).reset_index()
# Out:
#     stories  furnishingstatus     median  count
# 0         1                 0  3255000.0     89
# 1         1                 1  4550000.0     85
# 2         1                 2  4235000.0     53
# 3         2                 0  3493000.0     65
# 4         2                 1  4410000.0    115
# 5         2                 2  4973500.0     58
# 6         3                 0  5985000.0     12
# 7         3                 1  5530000.0     14
# 8         3                 2  6510000.0     13
# 9         4                 0  7087500.0     12
# 10        4                 1  7210000.0     13
# 11        4                 2  7420000.0     16

# %%
temp_df = df.groupby(['stories', 'furnishingstatus'])['price'].agg(['median', 'count']).reset_index()

# %%
temp_df[temp_df['count'] >=20]
# Out:
#    stories  furnishingstatus     median  count
# 0        1                 0  3255000.0     89
# 1        1                 1  4550000.0     85
# 2        1                 2  4235000.0     53
# 3        2                 0  3493000.0     65
# 4        2                 1  4410000.0    115
# 5        2                 2  4973500.0     58

# %%
#What is the 90th percentile of price for 3-bedroom houses that do NOT have access to the main road and have more than or equal to 1 parking space?

# %%
df['area'].quantile(0.9)
# Out:
# np.float64(7980.0)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns     Query     avgprice
# 0            6  noyesyes  1792.452830
# ...

# %%
df['bedrooms'].unique()
# Out:
# array([4, 3, 5, 2, 6, 1])

# %%
fil = df[(df['bedrooms'] == 3) & (df['mainroad'] == 'no')]

# %%
fil = fil[(fil['parking'] >= 1)]

# %%
fil.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 197  4956000  2800         3          2        2       no        no      yes
# 327  3990000  6480         3          1        2       no        no       no
# 443  3220000  4320         3          1        1       no        no       no
# 478  2940000  3600         3          1        2       no        no       no
# 480  2940000  3480         3          1        2       no        no       no
#
#     hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 197              no             yes        1       no                 1
# 327              no             yes        1       no                 1
# 443              no              no        1       no                 0
# 478              no              no        1       no                 0
# 480              no              no        1       no                 1
#
#      new_columns    Query     avgprice
# ...

# %%
fil['price'].quantile(0.9)
# Out:
# np.float64(4376400.0)

# %%
fil.shape
# Out:
# (7, 16)

# %%
#What is the most common furnishing status among the top 10% of most expensive houses within each number of bedrooms?

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns     Query     avgprice
# 0            6  noyesyes  1792.452830
# ...

# %%
df.groupby(['stories', 'furnishingstatus'])['price'].agg(['median', 'count']).reset_index()

# %%
df.groupby(['bedrooms'])['price'].agg(['median','count']).reset_index()
# Out:
#    bedrooms     median  count
# 0         1  2712500.0      2
# 1         2  3535000.0    136
# 2         3  4620000.0    300
# 3         4  5250000.0     95
# 4         5  5582500.0     10
# 5         6  4791500.0      2

# %%
#Select rows where price is in the top 20%, but only for houses with exactly 2 bathrooms and located on the main road.

# %%
df['price'].quantile(0.8)
# Out:
# np.float64(6093500.000000001)

# %%
condition_1 = df['price'] > df['price'].quantile(0.8)

# %%
df[condition_1]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 104   6195000  5500         3          2        1      yes       yes      yes
# 105   6160000  4500         3          1        4      yes        no       no
# 106   6160000  5450         4          2        1      yes        no      yes
# 107   6125000  6420         3          1        3      yes        no      yes
# 108   6107500  3240         4          1        3      yes        no       no
#
# ...

# %%
condition_2 = df['bathrooms'] == 2
condition_3 = df['mainroad'] == 'yes'

# %%
df[condition_1 & condition_2 & condition_3].head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000  7420         4          2        3      yes        no       no
# 2   12250000  9960         3          2        2      yes        no      yes
# 3   12215000  7500         4          2        2      yes        no      yes
# 9    9800000  5750         3          2        4      yes       yes       no
# 12   9310000  6550         4          2        2      yes        no       no
#
#    hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0               no             yes        2      yes                 2
# 2               no              no        2      yes                 1
# 3               no             yes        3      yes                 2
# 9               no             yes        1      yes                 0
# 12              no             yes        1      yes                 1
#
#     new_columns      Query     avgprice
# ...

# %%
# Assigning values to selective columns

# %%
df.loc[2:3, 'guestroom']= 'zgsgsgs'

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes   zgsgsgs      yes
# 3  12215000  7500         4          2        2      yes   zgsgsgs      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea  furnishingstatus  \
# 0              no             yes        2      yes                 2
# 1              no             yes        3       no                 2
# 2              no              no        2      yes                 1
# 3              no             yes        3      yes                 2
# 4              no             yes        2       no                 2
#
#    new_columns     Query     avgprice
# 0            6  noyesyes  1792.452830
# ...

# %%
#Set the furnishingstatus to 'luxury' if the house has >3 bedrooms, >2 bathrooms, and price is in top 10%
